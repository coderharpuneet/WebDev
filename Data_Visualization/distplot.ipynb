# %% [markdown]
# # Ditribution Plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('tips')

# %%
sns.displot(df['total_bill'],bins=30)

# %%
## Kernel Density Estimation (KDE)
# technique used to estimate the probability density function of continuous data.

# %%
sns.displot(df['total_bill'],bins=30,kde=True)

# %%
plt.subplot(1,2,1)
sns.displot(df['total_bill'],bins=30,kde=True)
plt.subplot(1,2,2)
sns.displot(df['tip'],bins=30,kde=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_13876\1607863837.py:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,2)

# %%
sns.jointplot(x='total_bill',y='tip',data=df, kind='scatter')

# %%
sns.jointplot(x='total_bill',y='tip',data=df, kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=df, kind='kde')

# %%
sns.jointplot(x='total_bill',y='tip',data=df, kind='reg')

# %%
# Pair Plot

sns.pairplot(df,hue='sex')

# %%
sns.pairplot(df,hue='size', palette='rainbow')

# %%
# Rugplot

sns.rugplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>
