# %% [markdown]
# # Pandas Series
#
# A series is a one dimensional labelled array capable of holding any data type. This axis labels are collectively called the index.

# %% [markdown]
# ## Creating Series
#
# There are multiple ways to create a pandas series.

# %%
# !pip install pandas numpy

# %%
import numpy as np
import pandas as pd

# %%
labels=['a','b','c']
my_list=[10,20,30]
arr=np.array([10,20,30])
d={1:10,2:20,3:30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %% [markdown]
# # Data Frames

# %%
# Creating a Data Frame

data={
     'Name' : ['John', 'Anna', 'Peter', 'Linda'],
     'Age' : [28,34,29,42],
     'City' : ['New York', 'Paris', 'Berlin', 'London'],
     'Salary' : [65000,70000,62000,85000]
}
df=pd.DataFrame(data)
print(df)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list=[
     ['John',28,'New York',65000],
     ['Anna',34,'Paris',70000],
     ['Peter',29,'Berlin',62000],
     ['Linda',42,'London',85000]
]
df2=pd.DataFrame(data_list)
columns=["Name","Age","City","Salary"]
df2=pd.DataFrame(data_list,columns=columns)
print(df2)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
# Selection and indexing of columns

df2['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: str

# %%
df2[["Name","City"]]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %%
# Creating a new column
df2["Designation"]=["Doctor","Eng.","Lawyer","Eng."]

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000        Eng.
# 2  Peter   29    Berlin   62000      Lawyer
# 3  Linda   42    London   85000        Eng.

# %%
df2["Designation"]=["Doctor","Eng.","Lawyer","Eng."]

# %%
# df2.drop(["Description"], axis=1)

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000        Eng.
# 2  Peter   29    Berlin   62000      Lawyer
# 3  Linda   42    London   85000        Eng.

# %%
# Permnently Delete
df2.drop(["Designation"], axis=1,inplace=True)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#Selecting Rows
df2.loc[0]
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
df2.iloc[3]
# Out:
# Name       Linda
# Age           42
# City      London
# Salary     85000
# Name: 3, dtype: object

# %%
# Selecting subsets of rows and columns
df2.loc[[0,1]][["City","Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
# Conditional Selection

# i only want to see whoe age is above 30
df2[df2["Age"]>30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
# I only want people whose age is above 30 and their city must be paris
df2[(df2["Age"]>30) & (df2["City"]=="Paris")]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000

# %% [markdown]
# # Missing Data

# %%
#Finding Missing Data
data={
     'A': [1,2,np.nan,4,5],
     'B': [np.nan,2,3,4,5],
     'C': [1,2,3,np.nan,np.nan],
     'D': [1,np.nan,np.nan,np.nan,5]
}
df=pd.DataFrame(data)

# %%
df
# Out:
#      A    B    C    D
# 0  1.0  NaN  1.0  1.0
# 1  2.0  2.0  2.0  NaN
# 2  NaN  3.0  3.0  NaN
# 3  4.0  4.0  NaN  NaN
# 4  5.0  5.0  NaN  5.0

# %%
df.isna().sum()
# Out:
# A    1
# B    1
# C    2
# D    3
# dtype: int64

# %%
df.isna().any()
# Out:
# A    True
# B    True
# C    True
# D    True
# dtype: bool

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
df.dropna(thresh=3)
# Out:
#      A    B    C    D
# 0  1.0  NaN  1.0  1.0
# 1  2.0  2.0  2.0  NaN
# 4  5.0  5.0  NaN  5.0

# %%
df.fillna(0)
# Out:
#      A    B    C    D
# 0  1.0  0.0  1.0  1.0
# 1  2.0  2.0  2.0  0.0
# 2  0.0  3.0  3.0  0.0
# 3  4.0  4.0  0.0  0.0
# 4  5.0  5.0  0.0  5.0

# %%
values={'A':0,'B':100,'C':300,'D':400}
df.fillna(value=values)
# Out:
#      A      B      C      D
# 0  1.0  100.0    1.0    1.0
# 1  2.0    2.0    2.0  400.0
# 2  0.0    3.0    3.0  400.0
# 3  4.0    4.0  300.0  400.0
# 4  5.0    5.0  300.0    5.0

# %% [markdown]
# # Merging Joining and Concatenation

# %%
employees = pd. DataFrame( {
'employee_id': [1, 2, 3, 4, 5],
'name': ['John', 'Anna', 'Peter', 'Linda', 'Bob'],
'department': ['HR', 'IT', 'Finance', 'IT', 'HR']

})

# DataFrame 2: Salary information
salaries = pd.DataFrame ( {
'employee_id': [1, 2, 3, 6, 7],
'salary': [60000, 80000, 65000, 70000, 90000],
'bonus': [5000, 10000, 7000, 8000, 12000]
})

# %%
employees
# Out:
#    employee_id   name department
# 0            1   John         HR
# 1            2   Anna         IT
# 2            3  Peter    Finance
# 3            4  Linda         IT
# 4            5    Bob         HR

# %%
salaries
# Out:
#    employee_id  salary  bonus
# 0            1   60000   5000
# 1            2   80000  10000
# 2            3   65000   7000
# 3            6   70000   8000
# 4            7   90000  12000

# %%
pd.merge(employees, salaries, on='employee_id', how='inner')
# Out:
#    employee_id   name department  salary  bonus
# 0            1   John         HR   60000   5000
# 1            2   Anna         IT   80000  10000
# 2            3  Peter    Finance   65000   7000

# %%
pd.merge(employees, salaries, on='employee_id', how='outer')
# Out:
#    employee_id   name department   salary    bonus
# 0            1   John         HR  60000.0   5000.0
# 1            2   Anna         IT  80000.0  10000.0
# 2            3  Peter    Finance  65000.0   7000.0
# 3            4  Linda         IT      NaN      NaN
# 4            5    Bob         HR      NaN      NaN
# 5            6    NaN        NaN  70000.0   8000.0
# 6            7    NaN        NaN  90000.0  12000.0

# %%
pd.merge(employees, salaries, on='employee_id', how='left')
# Out:
#    employee_id   name department   salary    bonus
# 0            1   John         HR  60000.0   5000.0
# 1            2   Anna         IT  80000.0  10000.0
# 2            3  Peter    Finance  65000.0   7000.0
# 3            4  Linda         IT      NaN      NaN
# 4            5    Bob         HR      NaN      NaN

# %%
pd.merge(employees, salaries, on='employee_id', how='right')
# Out:
#    employee_id   name department  salary  bonus
# 0            1   John         HR   60000   5000
# 1            2   Anna         IT   80000  10000
# 2            3  Peter    Finance   65000   7000
# 3            6    NaN        NaN   70000   8000
# 4            7    NaN        NaN   90000  12000

# %%
df1 = pd.DataFrame({
'A': ['A0', 'A1', 'A2'],
'B': ['B0', 'B1', 'B2'],
'C': ['CO', 'C1', 'C2']
})
df2 = pd.DataFrame({
'A': ['A3', 'A4', 'A5'],
'B': ['B3', 'B4', 'B5'],
'C': ['C3', 'C4', 'C5']
})

# %%
pd.concat([df1, df2])
# Out:
#     A   B   C
# 0  A0  B0  CO
# 1  A1  B1  C1
# 2  A2  B2  C2
# 0  A3  B3  C3
# 1  A4  B4  C4
# 2  A5  B5  C5

# %%
pd.concat([df1, df2],axis=1)
# Out:
#     A   B   C   A   B   C
# 0  A0  B0  CO  A3  B3  C3
# 1  A1  B1  C1  A4  B4  C4
# 2  A2  B2  C2  A5  B5  C5

# %%
df1 = pd.DataFrame({
'name': ['Alice', 'Bob', 'Charlie']
}, index=[1, 2, 3])

# Second DataFrame
df2 = pd.DataFrame({
'score': [85, 90, 75]
}, index=[2, 3, 4] )

# %%
df1
# Out:
#       name
# 1    Alice
# 2      Bob
# 3  Charlie

# %%
df2
# Out:
#    score
# 2     85
# 3     90
# 4     75

# %%
df1.join(df2)
# Out:
#       name  score
# 1    Alice    NaN
# 2      Bob   85.0
# 3  Charlie   90.0

# %%
df2.join(df1)
# Out:
#    score     name
# 2     85      Bob
# 3     90  Charlie
# 4     75      NaN

# %%
data = {
'Category': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
'Store': ['S1', 'S1', 'S2', 'S2', 'S1', '52', '52', 'S1'],
'Sales': [100, 200, 150, 250, 120, 180, 200, 300],
'Quantity': [10, 15, 12, 18, 8, 20, 15, 25],
'Date': pd.date_range( '2023-01-01', periods=8)
}

df= pd.DataFrame(data)

# %%
# Group by category and calculate the sum of sales
cat=df.groupby('Category')['Sales'].sum()

# %%
# Group by Store and calculate the sum of sales
store=df.groupby('Store')['Sales'].sum()
print(cat)
# Out:
# Category
# A    570
# B    930
# Name: Sales, dtype: int64

# %%
# Group by multiple columns
# Group by Category and Store
multi=df.groupby(['Category', 'Store'])['Sales'].sum()
print(multi)
# Out:
# Category  Store
# A         52       200
#           S1       220
#           S2       150
# B         52       180
#           S1       500
#           S2       250
# Name: Sales, dtype: int64

# %%
df['Sales'].mean()
# Out:
# np.float64(187.5)

# %%
df['Sales'].agg(['sum','mean','max','min','count','std','median'])
# Out:
# sum       1500.000000
# mean       187.500000
# max        300.000000
# min        100.000000
# count        8.000000
# std         66.062741
# median     190.000000
# Name: Sales, dtype: float64

# %% [markdown]
# # Pivot Tables

# %%
data = {
'Date': pd.date_range('2023-01-01', periods=20),
'Product': ['A', 'B', 'C', 'D'] * 5,
'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
'Sales': np. random. randint (100, 1000, 20),
'Units': np. random. randint(10, 100, 20),
'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}
df = pd. DataFrame(data)


df ['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt. quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    931     30   John  January      Q1
# 1  2023-01-02       B   West    730     37   Mary  January      Q1
# 2  2023-01-03       C  North    455     57    Bob  January      Q1
# 3  2023-01-04       D  South    260     60  Alice  January      Q1
# 4  2023-01-05       A   East    572     75   John  January      Q1
# 5  2023-01-06       B   West    534     58   Mary  January      Q1
# 6  2023-01-07       C  North    166     80    Bob  January      Q1
# 7  2023-01-08       D  South    628     21  Alice  January      Q1
# 8  2023-01-09       A   East    790     74   John  January      Q1
# 9  2023-01-10       B   West    367     12   Mary  January      Q1
# 10 2023-01-11       C  North    730     54    Bob  January      Q1
# 11 2023-01-12       D  South    614     97  Alice  January      Q1
# 12 2023-01-13       A   East    183     19   John  January      Q1
# 13 2023-01-14       B   West    421     83   Mary  January      Q1
# 14 2023-01-15       C  North    447     36    Bob  January      Q1
# 15 2023-01-16       D  South    380     17  Alice  January      Q1
# 16 2023-01-17       A   East    368     22   John  January      Q1
# 17 2023-01-18       B   West    438     55   Mary  January      Q1
# 18 2023-01-19       C  North    801     15    Bob  January      Q1
# 19 2023-01-20       D  South    900     62  Alice  January      Q1

# %%
pd.pivot_table(df, values='Sales', index='Region', columns='Product', aggfunc='sum')
# Out:
# Product       A       B       C       D
# Region
# East     2844.0     NaN     NaN     NaN
# North       NaN     NaN  2599.0     NaN
# South       NaN     NaN     NaN  2782.0
# West        NaN  2490.0     NaN     NaN

# %%
pivot2=pd.pivot_table(df, values=['Sales','Units'], index='Region', columns='Product', aggfunc='sum')
pivot2
# Out:
#           Sales                          Units
# Product       A       B       C       D      A      B      C      D
# Region
# East     2844.0     NaN     NaN     NaN  220.0    NaN    NaN    NaN
# North       NaN     NaN  2599.0     NaN    NaN    NaN  242.0    NaN
# South       NaN     NaN     NaN  2782.0    NaN    NaN    NaN  257.0
# West        NaN  2490.0     NaN     NaN    NaN  245.0    NaN    NaN

# %%
pd.crosstab(df['Region'], df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0

# %% [markdown]
# # Operations

# %%
# Data Frame Basic Operations
df1=pd.DataFrame({
     'A': [1,2,3,4,5],
     'B': [10,20,30,40,50],
     'C': [100,200,300,400,500]
})
df1
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
# 4  5  50  500

# %%
df1.shape
# Out:
# (5, 3)

# %%
df1.columns
# Out:
# Index(['A', 'B', 'C'], dtype='str')

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       5 non-null      int64
#  1   B       5 non-null      int64
#  2   C       5 non-null      int64
# dtypes: int64(3)
# memory usage: 252.0 bytes

# %%
df1.describe()
# Out:
#               A          B           C
# count  5.000000   5.000000    5.000000
# mean   3.000000  30.000000  300.000000
# std    1.581139  15.811388  158.113883
# min    1.000000  10.000000  100.000000
# 25%    2.000000  20.000000  200.000000
# 50%    3.000000  30.000000  300.000000
# 75%    4.000000  40.000000  400.000000
# max    5.000000  50.000000  500.000000

# %%
def square(x):
    return x**2

# %%
df["D"]=df1["B"].apply(square)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter       D
# 0  2023-01-01       A   East    931     30   John  January      Q1   100.0
# 1  2023-01-02       B   West    730     37   Mary  January      Q1   400.0
# 2  2023-01-03       C  North    455     57    Bob  January      Q1   900.0
# 3  2023-01-04       D  South    260     60  Alice  January      Q1  1600.0
# 4  2023-01-05       A   East    572     75   John  January      Q1  2500.0
# 5  2023-01-06       B   West    534     58   Mary  January      Q1     NaN
# 6  2023-01-07       C  North    166     80    Bob  January      Q1     NaN
# 7  2023-01-08       D  South    628     21  Alice  January      Q1     NaN
# 8  2023-01-09       A   East    790     74   John  January      Q1     NaN
# 9  2023-01-10       B   West    367     12   Mary  January      Q1     NaN
# 10 2023-01-11       C  North    730     54    Bob  January      Q1     NaN
# 11 2023-01-12       D  South    614     97  Alice  January      Q1     NaN
# 12 2023-01-13       A   East    183     19   John  January      Q1     NaN
# 13 2023-01-14       B   West    421     83   Mary  January      Q1     NaN
# 14 2023-01-15       C  North    447     36    Bob  January      Q1     NaN
# 15 2023-01-16       D  South    380     17  Alice  January      Q1     NaN
# 16 2023-01-17       A   East    368     22   John  January      Q1     NaN
# 17 2023-01-18       B   West    438     55   Mary  January      Q1     NaN
# 18 2023-01-19       C  North    801     15    Bob  January      Q1     NaN
# 19 2023-01-20       D  South    900     62  Alice  January      Q1     NaN

# %% [markdown]
# # Finding Data
